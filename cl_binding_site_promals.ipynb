# %%
import pandas as pd
import numpy as np
import bokeh.io
from bokeh.io import output_notebook
from bokeh.plotting import figure, output_file, gridplot, show
from bokeh.models import ColumnDataSource, Label, LabelSet, Range1d 
output_notebook()

with open('20_39_clc_align.txt', 'r') as file:
    text = file.read()
string_list = text.split('\n')
# print(string_list)

string_list_extract = []
for x in range(0, len(string_list)):
    if len(string_list[x]) > 200:
        string_list_extract.append(string_list[x])
# print(string_list_extract)

sequence_list_only = []
for x in range(0, len(string_list_extract)):
    seq_empty = []
    seq_empty = string_list_extract[x].split()
    for y in range(0, len(seq_empty)):
        if '-' in seq_empty[y]:
            sequence_list_only.append(seq_empty[y])

# print(sequence_list_only)

sequence_list_only_clean = []
for x in range(0, len(sequence_list_only)):
    seq_empty_1 = []
    # print(sequence_list_only[x])
    seq_empty_1 = sequence_list_only[x].split('\\')
    # print(seq_empty_1)
    sequence_list_only_clean.append(seq_empty_1[0])
    
# print(sequence_list_only_clean)

st_list = []
seq_2 = []
seq_3 = []
seq_4 = []
seq_5 = [] 
seq_6 = []
seq_7 = []
seq_8 = []
seq_9 = []
seq_10 = []
seq_11 = []
seq_12 = []
seq_13 = []
seq_14 = []
seq_15 = []
seq_16 = []
seq_17 = []
seq_18 = []
seq_19 = []
seq_20 = []

seq_list_of_lists = [st_list, seq_2, seq_3, seq_4, seq_5, seq_6, seq_7, seq_8, seq_9, seq_10, seq_11, seq_12, seq_13, seq_14, seq_15, seq_16, seq_17, seq_18, seq_19, seq_20]

for x in range(0, len(sequence_list_only_clean)):
    seq_list_of_lists[x] = [*sequence_list_only_clean[x]]
# print(seq_list_of_lists)

seq_list_of_lists_clean = []
for x in range(0, len(seq_list_of_lists)):
    if len(seq_list_of_lists[x]) > 0:
        seq_list_of_lists_clean.append(seq_list_of_lists[x])
# print(seq_list_of_lists_clean)

indeces_106_111 = []
indeces_146_150 = []
indeces_355_359 = []
indeces_445 = []
for x in range(0, len(seq_list_of_lists_clean[0])):
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'S':
            if seq_list_of_lists_clean[0][x + 2] == 'G':
                if seq_list_of_lists_clean[0][x + 3] == 'I':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_106_111.append(x)
                        indeces_106_111.append(x + 1)
                        indeces_106_111.append(x + 2)
                        indeces_106_111.append(x + 3)
                        indeces_106_111.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'R':
            if seq_list_of_lists_clean[0][x + 2] == 'E':
                if seq_list_of_lists_clean[0][x + 3] == 'G':
                     if seq_list_of_lists_clean[0][x + 4] == 'P':
                            indeces_146_150.append(x)
                            indeces_146_150.append(x + 1)
                            indeces_146_150.append(x + 2)
                            indeces_146_150.append(x + 3)
                            indeces_146_150.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'I':
            if seq_list_of_lists_clean[0][x + 2] == 'F':
                if seq_list_of_lists_clean[0][x + 3] == 'A':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_355_359.append(x)
                        indeces_355_359.append(x + 1)
                        indeces_355_359.append(x + 2)
                        indeces_355_359.append(x + 3)
                        indeces_355_359.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'P':
        if seq_list_of_lists_clean[0][x + 1] == 'L':
            if seq_list_of_lists_clean[0][x + 2] == 'Y':
                if seq_list_of_lists_clean[0][x + 3] == 'S':
                    if seq_list_of_lists_clean[0][x + 4] == 'T':
                        indeces_445.append(x + 2)
                    
print(indeces_106_111)
print(indeces_146_150)
print(indeces_355_359)
print(indeces_445)




sequences_106_111 = []
sequences_146_150 = []
sequences_355_359 = []
sequences_445 = []

for x in range(0, len(seq_list_of_lists_clean)):
    seq_1_empty = []
    seq_2_empty = []
    seq_3_empty = []
    seq_4_empty = []
    
    seq_1_empty.append(seq_list_of_lists_clean[x][113])
    seq_1_empty.append(seq_list_of_lists_clean[x][114])
    seq_1_empty.append(seq_list_of_lists_clean[x][115])
    seq_1_empty.append(seq_list_of_lists_clean[x][116])
    seq_1_empty.append(seq_list_of_lists_clean[x][117])
    
    sequences_106_111.append(seq_1_empty)
    
    seq_2_empty.append(seq_list_of_lists_clean[x][159])
    seq_2_empty.append(seq_list_of_lists_clean[x][160])
    seq_2_empty.append(seq_list_of_lists_clean[x][161])
    seq_2_empty.append(seq_list_of_lists_clean[x][162])
    seq_2_empty.append(seq_list_of_lists_clean[x][163])
    
    sequences_146_150.append(seq_2_empty)
    
    seq_3_empty.append(seq_list_of_lists_clean[x][394])
    seq_3_empty.append(seq_list_of_lists_clean[x][395])
    seq_3_empty.append(seq_list_of_lists_clean[x][396])
    seq_3_empty.append(seq_list_of_lists_clean[x][397])
    seq_3_empty.append(seq_list_of_lists_clean[x][398])
    
    sequences_355_359.append(seq_3_empty)
    
    seq_4_empty.append(seq_list_of_lists_clean[x][533])
    
    sequences_445.append(seq_4_empty)

print(sequences_106_111)
print(sequences_146_150)
print(sequences_355_359)
print(sequences_445)

position_1_106_111 = []
position_2_106_111 = []
position_3_106_111 = []
position_4_106_111 = []
position_5_106_111 = []
for x in range(0, len(sequences_106_111)):
    position_1_106_111.append(sequences_106_111[x][0])
    position_2_106_111.append(sequences_106_111[x][1])
    position_3_106_111.append(sequences_106_111[x][2])
    position_4_106_111.append(sequences_106_111[x][3])
    position_5_106_111.append(sequences_106_111[x][4])

df_106_111 = pd.DataFrame({'1': position_1_106_111, '2': position_2_106_111, '3': position_3_106_111, '4': position_4_106_111, '5': position_5_106_111})

position_1_146_150 = []
position_2_146_150 = []
position_3_146_150 = []
position_4_146_150 = []
position_5_146_150 = []
for x in range(0, len(sequences_146_150)):
    position_1_146_150.append(sequences_146_150[x][0])
    position_2_146_150.append(sequences_146_150[x][1])
    position_3_146_150.append(sequences_146_150[x][2])
    position_4_146_150.append(sequences_146_150[x][3])
    position_5_146_150.append(sequences_146_150[x][4])

df_146_150 = pd.DataFrame({'1': position_1_146_150, '2': position_2_146_150, '3': position_3_146_150, '4': position_4_146_150, '5': position_5_146_150})

position_1_355_359 = []
position_2_355_359 = []
position_3_355_359 = []
position_4_355_359 = []
position_5_355_359 = []
for x in range(0, len(sequences_355_359)):
    position_1_355_359.append(sequences_355_359[x][0])
    position_2_355_359.append(sequences_355_359[x][1])
    position_3_355_359.append(sequences_355_359[x][2])
    position_4_355_359.append(sequences_355_359[x][3])
    position_5_355_359.append(sequences_355_359[x][4])

df_355_359 = pd.DataFrame({'1': position_1_355_359, '2': position_2_355_359, '3': position_3_355_359, '4': position_4_355_359, '5': position_5_355_359})

position_1_445 = []
for x in range(0, len(sequences_445)):
    position_1_445.append(sequences_445[x][0])

df_445 = pd.DataFrame({'1': position_1_445})

def color_by_aa(val):
    if val == 'G':
        color = '#365A8C'
    elif val == 'A':
        color = '#365A8C'
    elif val == 'V':
        color = '#365A8C'
    elif val == 'L':
        color = '#365A8C'
    elif val == 'I':
        color = '#365A8C'
    elif val == 'M':
        color = '#365A8C'
    elif val == 'P':
        color = '#365A8C'
    elif val == 'F':
        color = '#365A8C'
    elif val == 'W':
        color = '#365A8C'
    elif val == 'S':
        color = '#277E8E'
    elif val == 'T':
        color = '#277E8E'
    elif val == 'N':
        color = '#277E8E'
    elif val == 'Q':
        color = '#277E8E'
    elif val == 'Y':
        color = '#277E8E'
    elif val == 'C':
        color = '#277E8E'
    elif val == 'K':
        color = '#9DD93A'
    elif val == 'R':
        color = '#9DD93A'
    elif val == 'H':
        color = '#9DD93A'
    elif val == 'D':
        color = '#9DD93A'
    elif val == 'E':
        color = '#9DD93A'
    return 'background-color: %s' % color    

display(df_106_111.style.applymap(color_by_aa))       
display(df_146_150.style.applymap(color_by_aa))   
display(df_355_359.style.applymap(color_by_aa))  
display(df_445.style.applymap(color_by_aa)) 
# color = 'red' if val < 0 else 'green'
    
# '#277E8E'
# '#9DD93A'
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1005">Loading BokehJS ...</span>
#     </div>
# [113, 114, 115, 116, 117]
# [159, 160, 161, 162, 163]
# [394, 395, 396, 397, 398]
# [533]
# [['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['V', 'K', 'G', 'N', 'N'], ['G', 'S', 'G', 'I', 'P'], ['G', 'H', 'G', 'T', 'E'], ['S', 'Q', 'G', 'N', 'N'], ['S', 'K', 'G', 'N', 'N'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'V', 'P'], ['P', 'R', 'L', 'M', 'P'], ['G', 'S', 'G', 'I', 'P'], ['E', 'K', 'G', 'S', 'N'], ['P', 'R', 'S', 'M', 'H'], ['R', 'Q', 'G', 'M', 'G'], ['G', 'S', 'G', 'I', 'P'], ['A', 'K', 'G', 'M', 'A']]
# ...

# %%
with open('30_59_clc_align.txt', 'r') as file:
    text = file.read()
string_list = text.split('\n')
# print(string_list)

string_list_extract = []
for x in range(0, len(string_list)):
    if len(string_list[x]) > 200:
        string_list_extract.append(string_list[x])
# print(string_list_extract)

sequence_list_only = []
for x in range(0, len(string_list_extract)):
    seq_empty = []
    seq_empty = string_list_extract[x].split()
    for y in range(0, len(seq_empty)):
        if '-' in seq_empty[y]:
            sequence_list_only.append(seq_empty[y])

# print(sequence_list_only)

sequence_list_only_clean = []
for x in range(0, len(sequence_list_only)):
    seq_empty_1 = []
    # print(sequence_list_only[x])
    seq_empty_1 = sequence_list_only[x].split('\\')
    # print(seq_empty_1)
    sequence_list_only_clean.append(seq_empty_1[0])
    
# print(sequence_list_only_clean)

st_list = []
seq_2 = []
seq_3 = []
seq_4 = []
seq_5 = [] 
seq_6 = []
seq_7 = []
seq_8 = []
seq_9 = []
seq_10 = []
seq_11 = []
seq_12 = []
seq_13 = []
seq_14 = []
seq_15 = []
seq_16 = []
seq_17 = []
seq_18 = []
seq_19 = []
seq_20 = []

seq_list_of_lists = [st_list, seq_2, seq_3, seq_4, seq_5, seq_6, seq_7, seq_8, seq_9, seq_10, seq_11, seq_12, seq_13, seq_14, seq_15, seq_16, seq_17, seq_18, seq_19, seq_20]

for x in range(0, len(sequence_list_only_clean)):
    seq_list_of_lists[x] = [*sequence_list_only_clean[x]]
# print(seq_list_of_lists)

seq_list_of_lists_clean = []
for x in range(0, len(seq_list_of_lists)):
    if len(seq_list_of_lists[x]) > 0:
        seq_list_of_lists_clean.append(seq_list_of_lists[x])
# print(seq_list_of_lists_clean)

indeces_106_111 = []
indeces_146_150 = []
indeces_355_359 = []
indeces_445 = []
for x in range(0, len(seq_list_of_lists_clean[0])):
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'S':
            if seq_list_of_lists_clean[0][x + 2] == 'G':
                if seq_list_of_lists_clean[0][x + 3] == 'I':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_106_111.append(x)
                        indeces_106_111.append(x + 1)
                        indeces_106_111.append(x + 2)
                        indeces_106_111.append(x + 3)
                        indeces_106_111.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'R':
            if seq_list_of_lists_clean[0][x + 2] == 'E':
                if seq_list_of_lists_clean[0][x + 3] == 'G':
                     if seq_list_of_lists_clean[0][x + 4] == 'P':
                            indeces_146_150.append(x)
                            indeces_146_150.append(x + 1)
                            indeces_146_150.append(x + 2)
                            indeces_146_150.append(x + 3)
                            indeces_146_150.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'I':
            if seq_list_of_lists_clean[0][x + 2] == 'F':
                if seq_list_of_lists_clean[0][x + 3] == 'A':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_355_359.append(x)
                        indeces_355_359.append(x + 1)
                        indeces_355_359.append(x + 2)
                        indeces_355_359.append(x + 3)
                        indeces_355_359.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'P':
        if seq_list_of_lists_clean[0][x + 1] == 'L':
            if seq_list_of_lists_clean[0][x + 2] == 'Y':
                if seq_list_of_lists_clean[0][x + 3] == 'S':
                    if seq_list_of_lists_clean[0][x + 4] == 'T':
                        indeces_445.append(x + 2)
                    
print(indeces_106_111)
print(indeces_146_150)
print(indeces_355_359)
print(indeces_445)




sequences_106_111 = []
sequences_146_150 = []
sequences_355_359 = []
sequences_445 = []

for x in range(0, len(seq_list_of_lists_clean)):
    seq_1_empty = []
    seq_2_empty = []
    seq_3_empty = []
    seq_4_empty = []
    
    seq_1_empty.append(seq_list_of_lists_clean[x][142])
    seq_1_empty.append(seq_list_of_lists_clean[x][143])
    seq_1_empty.append(seq_list_of_lists_clean[x][144])
    seq_1_empty.append(seq_list_of_lists_clean[x][145])
    seq_1_empty.append(seq_list_of_lists_clean[x][146])
    
    sequences_106_111.append(seq_1_empty)
    
    seq_2_empty.append(seq_list_of_lists_clean[x][183])
    seq_2_empty.append(seq_list_of_lists_clean[x][184])
    seq_2_empty.append(seq_list_of_lists_clean[x][185])
    seq_2_empty.append(seq_list_of_lists_clean[x][186])
    seq_2_empty.append(seq_list_of_lists_clean[x][187])
    
    sequences_146_150.append(seq_2_empty)
    
    seq_3_empty.append(seq_list_of_lists_clean[x][401])
    seq_3_empty.append(seq_list_of_lists_clean[x][402])
    seq_3_empty.append(seq_list_of_lists_clean[x][403])
    seq_3_empty.append(seq_list_of_lists_clean[x][404])
    seq_3_empty.append(seq_list_of_lists_clean[x][405])
    
    sequences_355_359.append(seq_3_empty)
    
    seq_4_empty.append(seq_list_of_lists_clean[x][495])
    
    sequences_445.append(seq_4_empty)

print(sequences_106_111)
print(sequences_146_150)
print(sequences_355_359)
print(sequences_445)

position_1_106_111 = []
position_2_106_111 = []
position_3_106_111 = []
position_4_106_111 = []
position_5_106_111 = []
for x in range(0, len(sequences_106_111)):
    position_1_106_111.append(sequences_106_111[x][0])
    position_2_106_111.append(sequences_106_111[x][1])
    position_3_106_111.append(sequences_106_111[x][2])
    position_4_106_111.append(sequences_106_111[x][3])
    position_5_106_111.append(sequences_106_111[x][4])

df_106_111 = pd.DataFrame({'1': position_1_106_111, '2': position_2_106_111, '3': position_3_106_111, '4': position_4_106_111, '5': position_5_106_111})

position_1_146_150 = []
position_2_146_150 = []
position_3_146_150 = []
position_4_146_150 = []
position_5_146_150 = []
for x in range(0, len(sequences_146_150)):
    position_1_146_150.append(sequences_146_150[x][0])
    position_2_146_150.append(sequences_146_150[x][1])
    position_3_146_150.append(sequences_146_150[x][2])
    position_4_146_150.append(sequences_146_150[x][3])
    position_5_146_150.append(sequences_146_150[x][4])

df_146_150 = pd.DataFrame({'1': position_1_146_150, '2': position_2_146_150, '3': position_3_146_150, '4': position_4_146_150, '5': position_5_146_150})

position_1_355_359 = []
position_2_355_359 = []
position_3_355_359 = []
position_4_355_359 = []
position_5_355_359 = []
for x in range(0, len(sequences_355_359)):
    position_1_355_359.append(sequences_355_359[x][0])
    position_2_355_359.append(sequences_355_359[x][1])
    position_3_355_359.append(sequences_355_359[x][2])
    position_4_355_359.append(sequences_355_359[x][3])
    position_5_355_359.append(sequences_355_359[x][4])

df_355_359 = pd.DataFrame({'1': position_1_355_359, '2': position_2_355_359, '3': position_3_355_359, '4': position_4_355_359, '5': position_5_355_359})

position_1_445 = []
for x in range(0, len(sequences_445)):
    position_1_445.append(sequences_445[x][0])

df_445 = pd.DataFrame({'1': position_1_445})

def color_by_aa(val):
    if val == 'G':
        color = '#365A8C'
    elif val == 'A':
        color = '#365A8C'
    elif val == 'V':
        color = '#365A8C'
    elif val == 'L':
        color = '#365A8C'
    elif val == 'I':
        color = '#365A8C'
    elif val == 'M':
        color = '#365A8C'
    elif val == 'P':
        color = '#365A8C'
    elif val == 'F':
        color = '#365A8C'
    elif val == 'W':
        color = '#365A8C'
    elif val == 'S':
        color = '#277E8E'
    elif val == 'T':
        color = '#277E8E'
    elif val == 'N':
        color = '#277E8E'
    elif val == 'Q':
        color = '#277E8E'
    elif val == 'Y':
        color = '#277E8E'
    elif val == 'C':
        color = '#277E8E'
    elif val == 'K':
        color = '#9DD93A'
    elif val == 'R':
        color = '#9DD93A'
    elif val == 'H':
        color = '#9DD93A'
    elif val == 'D':
        color = '#9DD93A'
    elif val == 'E':
        color = '#9DD93A'
        color = '#9DD93A'
    elif val == '-':
        color = '#808080'
    return 'background-color: %s' % color    

display(df_106_111.style.applymap(color_by_aa))       
display(df_146_150.style.applymap(color_by_aa))   
display(df_355_359.style.applymap(color_by_aa))  
display(df_445.style.applymap(color_by_aa)) 
# color = 'red' if val < 0 else 'green'
    
# '#277E8E'
# Out:
# [142, 143, 144, 145, 146]
# [183, 184, 185, 186, 187]
# [401, 402, 403, 404, 405]
# [495]
# [['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['G', 'K', 'P', 'L', 'I'], ['-', '-', 'P', 'I', 'V'], ['Q', 'I', 'G', 'V', 'V'], ['G', 'H', 'G', 'T', 'E'], ['G', 'S', 'G', 'V', 'N'], ['G', 'S', 'G', 'I', 'P'], ['D', 'A', 'G', 'N', 'N'], ['G', 'S', 'G', 'I', 'P'], ['G', 'H', 'G', 'I', 'P']]
# ...

# %%
with open('60_79_clc_align.txt', 'r') as file:
    text = file.read()
string_list = text.split('\n')
# print(string_list)

string_list_extract = []
for x in range(0, len(string_list)):
    if len(string_list[x]) > 200:
        string_list_extract.append(string_list[x])
# print(string_list_extract)

sequence_list_only = []
for x in range(0, len(string_list_extract)):
    seq_empty = []
    seq_empty = string_list_extract[x].split()
    for y in range(0, len(seq_empty)):
        if '-' in seq_empty[y]:
            sequence_list_only.append(seq_empty[y])

# print(sequence_list_only)

sequence_list_only_clean = []
for x in range(0, len(sequence_list_only)):
    seq_empty_1 = []
    # print(sequence_list_only[x])
    seq_empty_1 = sequence_list_only[x].split('\\')
    # print(seq_empty_1)
    sequence_list_only_clean.append(seq_empty_1[0])
    
# print(sequence_list_only_clean)

st_list = []
seq_2 = []
seq_3 = []
seq_4 = []
seq_5 = [] 
seq_6 = []
seq_7 = []
seq_8 = []
seq_9 = []
seq_10 = []
seq_11 = []
seq_12 = []
seq_13 = []
seq_14 = []
seq_15 = []
seq_16 = []
seq_17 = []
seq_18 = []
seq_19 = []
seq_20 = []

seq_list_of_lists = [st_list, seq_2, seq_3, seq_4, seq_5, seq_6, seq_7, seq_8, seq_9, seq_10, seq_11, seq_12, seq_13, seq_14, seq_15, seq_16, seq_17, seq_18, seq_19, seq_20]

for x in range(0, len(sequence_list_only_clean)):
    seq_list_of_lists[x] = [*sequence_list_only_clean[x]]
# print(seq_list_of_lists)

seq_list_of_lists_clean = []
for x in range(0, len(seq_list_of_lists)):
    if len(seq_list_of_lists[x]) > 0:
        seq_list_of_lists_clean.append(seq_list_of_lists[x])
# print(seq_list_of_lists_clean)

indeces_106_111 = []
indeces_146_150 = []
indeces_355_359 = []
indeces_445 = []
print(seq_list_of_lists_clean[0])

for x in range(0, len(seq_list_of_lists_clean[0])):
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == '-':
            if seq_list_of_lists_clean[0][x + 2] == 'S':
                if seq_list_of_lists_clean[0][x + 3] == 'G':
                    if seq_list_of_lists_clean[0][x + 4] == 'I':
                        if seq_list_of_lists_clean[0][x + 5] == 'P':
                            indeces_106_111.append(x)
                            indeces_106_111.append(x + 1)
                            indeces_106_111.append(x + 2)
                            indeces_106_111.append(x + 3)
                            indeces_106_111.append(x + 4)
                            indeces_106_111.append(x + 5)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'R':
            if seq_list_of_lists_clean[0][x + 2] == 'E':
                if seq_list_of_lists_clean[0][x + 3] == 'G':
                     if seq_list_of_lists_clean[0][x + 4] == 'P':
                            indeces_146_150.append(x)
                            indeces_146_150.append(x + 1)
                            indeces_146_150.append(x + 2)
                            indeces_146_150.append(x + 3)
                            indeces_146_150.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'I':
            if seq_list_of_lists_clean[0][x + 2] == 'F':
                if seq_list_of_lists_clean[0][x + 3] == 'A':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_355_359.append(x)
                        indeces_355_359.append(x + 1)
                        indeces_355_359.append(x + 2)
                        indeces_355_359.append(x + 3)
                        indeces_355_359.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'P':
        if seq_list_of_lists_clean[0][x + 1] == 'L':
            if seq_list_of_lists_clean[0][x + 2] == 'Y':
                if seq_list_of_lists_clean[0][x + 3] == 'S':
                    if seq_list_of_lists_clean[0][x + 4] == 'T':
                        indeces_445.append(x + 2)
                    
print(indeces_106_111)
print(indeces_146_150)
print(indeces_355_359)
print(indeces_445)

sequences_106_111 = []
sequences_146_150 = []
sequences_355_359 = []
sequences_445 = []

for x in range(0, len(seq_list_of_lists_clean)):
    seq_1_empty = []
    seq_2_empty = []
    seq_3_empty = []
    seq_4_empty = []
    
    seq_1_empty.append(seq_list_of_lists_clean[x][200])
    seq_1_empty.append(seq_list_of_lists_clean[x][201])
    seq_1_empty.append(seq_list_of_lists_clean[x][202])
    seq_1_empty.append(seq_list_of_lists_clean[x][203])
    seq_1_empty.append(seq_list_of_lists_clean[x][204])
    seq_1_empty.append(seq_list_of_lists_clean[x][205])
    
    sequences_106_111.append(seq_1_empty)
    
    seq_2_empty.append(seq_list_of_lists_clean[x][248])
    seq_2_empty.append(seq_list_of_lists_clean[x][249])
    seq_2_empty.append(seq_list_of_lists_clean[x][250])
    seq_2_empty.append(seq_list_of_lists_clean[x][251])
    seq_2_empty.append(seq_list_of_lists_clean[x][252])
    
    sequences_146_150.append(seq_2_empty)
    
    seq_3_empty.append(seq_list_of_lists_clean[x][495])
    seq_3_empty.append(seq_list_of_lists_clean[x][496])
    seq_3_empty.append(seq_list_of_lists_clean[x][497])
    seq_3_empty.append(seq_list_of_lists_clean[x][498])
    seq_3_empty.append(seq_list_of_lists_clean[x][499])
    
    sequences_355_359.append(seq_3_empty)
    
    seq_4_empty.append(seq_list_of_lists_clean[x][591])
    
    sequences_445.append(seq_4_empty)

print(sequences_106_111)
print(sequences_146_150)
print(sequences_355_359)
print(sequences_445)

position_1_106_111 = []
position_2_106_111 = []
position_3_106_111 = []
position_4_106_111 = []
position_5_106_111 = []
position_6_106_111 = []
for x in range(0, len(sequences_106_111)):
    position_1_106_111.append(sequences_106_111[x][0])
    position_2_106_111.append(sequences_106_111[x][1])
    position_3_106_111.append(sequences_106_111[x][2])
    position_4_106_111.append(sequences_106_111[x][3])
    position_5_106_111.append(sequences_106_111[x][4])
    position_6_106_111.append(sequences_106_111[x][5])

df_106_111 = pd.DataFrame({'1': position_1_106_111, '2': position_2_106_111, '3': position_3_106_111, '4': position_4_106_111, '5': position_5_106_111, '6': position_6_106_111})

position_1_146_150 = []
position_2_146_150 = []
position_3_146_150 = []
position_4_146_150 = []
position_5_146_150 = []
for x in range(0, len(sequences_146_150)):
    position_1_146_150.append(sequences_146_150[x][0])
    position_2_146_150.append(sequences_146_150[x][1])
    position_3_146_150.append(sequences_146_150[x][2])
    position_4_146_150.append(sequences_146_150[x][3])
    position_5_146_150.append(sequences_146_150[x][4])

df_146_150 = pd.DataFrame({'1': position_1_146_150, '2': position_2_146_150, '3': position_3_146_150, '4': position_4_146_150, '5': position_5_146_150})

position_1_355_359 = []
position_2_355_359 = []
position_3_355_359 = []
position_4_355_359 = []
position_5_355_359 = []
for x in range(0, len(sequences_355_359)):
    position_1_355_359.append(sequences_355_359[x][0])
    position_2_355_359.append(sequences_355_359[x][1])
    position_3_355_359.append(sequences_355_359[x][2])
    position_4_355_359.append(sequences_355_359[x][3])
    position_5_355_359.append(sequences_355_359[x][4])

df_355_359 = pd.DataFrame({'1': position_1_355_359, '2': position_2_355_359, '3': position_3_355_359, '4': position_4_355_359, '5': position_5_355_359})

position_1_445 = []
for x in range(0, len(sequences_445)):
    position_1_445.append(sequences_445[x][0])

df_445 = pd.DataFrame({'1': position_1_445})

def color_by_aa(val):
    if val == 'G':
        color = '#365A8C'
    elif val == 'A':
        color = '#365A8C'
    elif val == 'V':
        color = '#365A8C'
    elif val == 'L':
        color = '#365A8C'
    elif val == 'I':
        color = '#365A8C'
    elif val == 'M':
        color = '#365A8C'
    elif val == 'P':
        color = '#365A8C'
    elif val == 'F':
        color = '#365A8C'
    elif val == 'W':
        color = '#365A8C'
    elif val == 'S':
        color = '#277E8E'
    elif val == 'T':
        color = '#277E8E'
    elif val == 'N':
        color = '#277E8E'
    elif val == 'Q':
        color = '#277E8E'
    elif val == 'Y':
        color = '#277E8E'
    elif val == 'C':
        color = '#277E8E'
    elif val == 'K':
        color = '#9DD93A'
    elif val == 'R':
        color = '#9DD93A'
    elif val == 'H':
        color = '#9DD93A'
    elif val == 'D':
        color = '#9DD93A'
    elif val == 'E':
        color = '#9DD93A'
    elif val == '-':
        color = '#808080'
    return 'background-color: %s' % color    

display(df_106_111.style.applymap(color_by_aa))       
display(df_146_150.style.applymap(color_by_aa))   
display(df_355_359.style.applymap(color_by_aa))  
display(df_445.style.applymap(color_by_aa)) 
# color = 'red' if val < 0 else 'green'
    
# '#277E8E'
# '#9DD93A'
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M', 'K', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'T', 'D', 'T', 'S', 'T', 'F', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'L', 'A', 'Q', 'Q', 'I', 'V', 'R', 'L', 'R', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'R', 'R', 'D', 'Q', 'I', 'R', 'R', 'L', 'M', 'Q', 'R', 'D', 'K', 'T', 'P', 'L', 'A', 'I', 'L', 'F', 'M', 'A', 'A', 'V', 'V', 'G', 'T', '-', '-', '-', '-', 'L', 'T', 'G', 'L', 'V', 'G', 'V', 'A', 'F', 'E', 'K', 'A', 'V', 'S', 'W', 'V', 'Q', 'N', 'M', 'R', 'I', 'G', 'A', 'L', 'V', 'Q', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'V', 'A', 'D', 'H', 'A', 'F', 'L', 'L', 'W', '-', '-', '-', '-', '-', 'P', 'L', 'A', 'F', 'I', 'L', 'S', 'A', 'L', 'L', 'A', 'M', 'V', 'G', 'Y', 'F', 'L', 'V', 'R', 'K', 'F', 'A', 'P', 'E', 'A', 'G
# ...

# %%
with open('selected_clc_align.txt', 'r') as file:
    text = file.read()
string_list = text.split('\n')
# print(string_list)

string_list_extract = []
for x in range(0, len(string_list)):
    if len(string_list[x]) > 200:
        string_list_extract.append(string_list[x])
# print(string_list_extract)

sequence_list_only = []
for x in range(0, len(string_list_extract)):
    seq_empty = []
    seq_empty = string_list_extract[x].split()
    for y in range(0, len(seq_empty)):
        if '-' in seq_empty[y]:
            sequence_list_only.append(seq_empty[y])

# print(sequence_list_only)

sequence_list_only_clean = []
for x in range(0, len(sequence_list_only)):
    seq_empty_1 = []
    # print(sequence_list_only[x])
    seq_empty_1 = sequence_list_only[x].split('\\')
    # print(seq_empty_1)
    sequence_list_only_clean.append(seq_empty_1[0])
    
# print(sequence_list_only_clean)

st_list = []
seq_2 = []
seq_3 = []
seq_4 = []
seq_5 = [] 
seq_6 = []
seq_7 = []
seq_8 = []
seq_9 = []
seq_10 = []
seq_11 = []
seq_12 = []
seq_13 = []
seq_14 = []
seq_15 = []
seq_16 = []
seq_17 = []
seq_18 = []
seq_19 = []
seq_20 = []

seq_list_of_lists = [st_list, seq_2, seq_3, seq_4, seq_5, seq_6, seq_7, seq_8, seq_9, seq_10, seq_11, seq_12, seq_13, seq_14, seq_15, seq_16, seq_17, seq_18, seq_19, seq_20]

for x in range(0, len(sequence_list_only_clean)):
    seq_list_of_lists[x] = [*sequence_list_only_clean[x]]
# print(seq_list_of_lists)

seq_list_of_lists_clean = []
for x in range(0, len(seq_list_of_lists)):
    if len(seq_list_of_lists[x]) > 0:
        seq_list_of_lists_clean.append(seq_list_of_lists[x])
# print(seq_list_of_lists_clean)

indeces_106_111 = []
indeces_146_150 = []
indeces_355_359 = []
indeces_445 = []
for x in range(0, len(seq_list_of_lists_clean[0])):
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'S':
            if seq_list_of_lists_clean[0][x + 2] == 'G':
                if seq_list_of_lists_clean[0][x + 3] == 'I':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_106_111.append(x)
                        indeces_106_111.append(x + 1)
                        indeces_106_111.append(x + 2)
                        indeces_106_111.append(x + 3)
                        indeces_106_111.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'R':
            if seq_list_of_lists_clean[0][x + 2] == 'E':
                if seq_list_of_lists_clean[0][x + 3] == 'G':
                     if seq_list_of_lists_clean[0][x + 4] == 'P':
                            indeces_146_150.append(x)
                            indeces_146_150.append(x + 1)
                            indeces_146_150.append(x + 2)
                            indeces_146_150.append(x + 3)
                            indeces_146_150.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'G':
        if seq_list_of_lists_clean[0][x + 1] == 'I':
            if seq_list_of_lists_clean[0][x + 2] == 'F':
                if seq_list_of_lists_clean[0][x + 3] == 'A':
                    if seq_list_of_lists_clean[0][x + 4] == 'P':
                        indeces_355_359.append(x)
                        indeces_355_359.append(x + 1)
                        indeces_355_359.append(x + 2)
                        indeces_355_359.append(x + 3)
                        indeces_355_359.append(x + 4)
    if seq_list_of_lists_clean[0][x] == 'P':
        if seq_list_of_lists_clean[0][x + 1] == 'L':
            if seq_list_of_lists_clean[0][x + 2] == 'Y':
                if seq_list_of_lists_clean[0][x + 3] == 'S':
                    if seq_list_of_lists_clean[0][x + 4] == 'T':
                        indeces_445.append(x + 2)
                    
print(indeces_106_111)
print(indeces_146_150)
print(indeces_355_359)
print(indeces_445)




sequences_106_111 = []
sequences_146_150 = []
sequences_355_359 = []
sequences_445 = []

for x in range(0, len(seq_list_of_lists_clean)):
    seq_1_empty = []
    seq_2_empty = []
    seq_3_empty = []
    seq_4_empty = []
    
    seq_1_empty.append(seq_list_of_lists_clean[x][118])
    seq_1_empty.append(seq_list_of_lists_clean[x][119])
    seq_1_empty.append(seq_list_of_lists_clean[x][120])
    seq_1_empty.append(seq_list_of_lists_clean[x][121])
    seq_1_empty.append(seq_list_of_lists_clean[x][122])
    
    sequences_106_111.append(seq_1_empty)
    
    seq_2_empty.append(seq_list_of_lists_clean[x][159])
    seq_2_empty.append(seq_list_of_lists_clean[x][160])
    seq_2_empty.append(seq_list_of_lists_clean[x][161])
    seq_2_empty.append(seq_list_of_lists_clean[x][162])
    seq_2_empty.append(seq_list_of_lists_clean[x][163])
    
    sequences_146_150.append(seq_2_empty)
    
    seq_3_empty.append(seq_list_of_lists_clean[x][381])
    seq_3_empty.append(seq_list_of_lists_clean[x][382])
    seq_3_empty.append(seq_list_of_lists_clean[x][383])
    seq_3_empty.append(seq_list_of_lists_clean[x][384])
    seq_3_empty.append(seq_list_of_lists_clean[x][385])
    
    sequences_355_359.append(seq_3_empty)
    
    seq_4_empty.append(seq_list_of_lists_clean[x][472])
    
    sequences_445.append(seq_4_empty)

print(sequences_106_111)
print(sequences_146_150)
print(sequences_355_359)
print(sequences_445)

position_1_106_111 = []
position_2_106_111 = []
position_3_106_111 = []
position_4_106_111 = []
position_5_106_111 = []
for x in range(0, len(sequences_106_111)):
    position_1_106_111.append(sequences_106_111[x][0])
    position_2_106_111.append(sequences_106_111[x][1])
    position_3_106_111.append(sequences_106_111[x][2])
    position_4_106_111.append(sequences_106_111[x][3])
    position_5_106_111.append(sequences_106_111[x][4])

df_106_111 = pd.DataFrame({'1': position_1_106_111, '2': position_2_106_111, '3': position_3_106_111, '4': position_4_106_111, '5': position_5_106_111})

position_1_146_150 = []
position_2_146_150 = []
position_3_146_150 = []
position_4_146_150 = []
position_5_146_150 = []
for x in range(0, len(sequences_146_150)):
    position_1_146_150.append(sequences_146_150[x][0])
    position_2_146_150.append(sequences_146_150[x][1])
    position_3_146_150.append(sequences_146_150[x][2])
    position_4_146_150.append(sequences_146_150[x][3])
    position_5_146_150.append(sequences_146_150[x][4])

df_146_150 = pd.DataFrame({'1': position_1_146_150, '2': position_2_146_150, '3': position_3_146_150, '4': position_4_146_150, '5': position_5_146_150})

position_1_355_359 = []
position_2_355_359 = []
position_3_355_359 = []
position_4_355_359 = []
position_5_355_359 = []
for x in range(0, len(sequences_355_359)):
    position_1_355_359.append(sequences_355_359[x][0])
    position_2_355_359.append(sequences_355_359[x][1])
    position_3_355_359.append(sequences_355_359[x][2])
    position_4_355_359.append(sequences_355_359[x][3])
    position_5_355_359.append(sequences_355_359[x][4])

df_355_359 = pd.DataFrame({'1': position_1_355_359, '2': position_2_355_359, '3': position_3_355_359, '4': position_4_355_359, '5': position_5_355_359})

position_1_445 = []
for x in range(0, len(sequences_445)):
    position_1_445.append(sequences_445[x][0])

df_445 = pd.DataFrame({'1': position_1_445})

def color_by_aa(val):
    if val == 'G':
        color = '#365A8C'
    elif val == 'A':
        color = '#365A8C'
    elif val == 'V':
        color = '#365A8C'
    elif val == 'L':
        color = '#365A8C'
    elif val == 'I':
        color = '#365A8C'
    elif val == 'M':
        color = '#365A8C'
    elif val == 'P':
        color = '#365A8C'
    elif val == 'F':
        color = '#365A8C'
    elif val == 'W':
        color = '#365A8C'
    elif val == 'S':
        color = '#277E8E'
    elif val == 'T':
        color = '#277E8E'
    elif val == 'N':
        color = '#277E8E'
    elif val == 'Q':
        color = '#277E8E'
    elif val == 'Y':
        color = '#277E8E'
    elif val == 'C':
        color = '#277E8E'
    elif val == 'K':
        color = '#9DD93A'
    elif val == 'R':
        color = '#9DD93A'
    elif val == 'H':
        color = '#9DD93A'
    elif val == 'D':
        color = '#9DD93A'
    elif val == 'E':
        color = '#9DD93A'
        color = '#9DD93A'
    elif val == '-':
        color = '#808080'
    return 'background-color: %s' % color    

display(df_106_111.style.applymap(color_by_aa))       
display(df_146_150.style.applymap(color_by_aa))   
display(df_355_359.style.applymap(color_by_aa))  
display(df_445.style.applymap(color_by_aa)) 
# color = 'red' if val < 0 else 'green'
    
# '#277E8E'
# Out:
# [118, 119, 120, 121, 122]
# [159, 160, 161, 162, 163]
# [381, 382, 383, 384, 385]
# [472]
# [['G', 'S', 'G', 'I', 'P'], ['G', 'S', 'G', 'I', 'P'], ['N', 'K', 'G', 'I', 'K'], ['A', 'R', 'G', 'N', 'N'], ['G', 'R', 'P', 'A', 'V'], ['G', 'S', 'G', 'I', 'P'], ['G', 'H', 'G', 'G', 'P']]
# [['G', 'R', 'E', 'G', 'P'], ['G', 'I', 'E', 'G', 'P'], ['G', 'I', 'E', 'V', 'S'], ['G', 'R', 'E', 'G', 'T'], ['G', 'R', 'E', 'N', 'A'], ['G', 'R', 'E', 'G', 'P'], ['G', 'P', 'E', 'N', 'P']]
# [['G', 'I', 'F', 'A', 'P'], ['G', 'I', 'L', 'F', 'P'], ['G', 'V', 'F', 'A', 'P'], ['G', 'E', 'V', 'T', 'P'], ['G', 'N', 'L', 'T', 'P'], ['G', 'L', 'F', 'A', 'P'], ['G', 'R', 'I', 'F', 'P']]
# [['Y'], ['Y'], ['Y'], ['Y'], ['I'], ['Y'], ['-']]
# <style type="text/css">
# ...
